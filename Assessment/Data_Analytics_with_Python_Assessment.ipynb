# %% [markdown]
# <a href="https://colab.research.google.com/github/AMANBHA1/Data-Analytics-Workshop/blob/main/Assessment/Data_Analytics_with_Python_Assessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# This assessment aims to evaluate your understanding and application of the concepts covered in the Data Analytics course. You will be tasked with analyzing a dataset related to remote work and mental health, utilizing various data manipulation, statistical analysis, and visualization techniques learned throughout the course. This exercise will help reinforce your skills in data handling, exploratory analysis, and drawing meaningful insights from data.
#
# ### Submission Details:
#
# The deadline for submission is 16 November at 11:59 PM. Specific submission details will be shared with you shortly.
#
# ### Passing Criteria:
#
# To successfully pass this assessment, you must achieve a score of 80% or higher.
# We encourage you to engage with the material and demonstrate your analytical skills. Good luck!
#
#
# ---

# %% [markdown]
# # Section 1 - Beginner (25%)

# %% [markdown]
# ## Shopping Cart System with Discounts
#
# Write a Python program to simulate a shopping cart system for an online store. The program will calculate the total cost of items, apply discounts, and check if the total exceeds a specified budget.

# %% [markdown]
# 1.	Variables and Lists:
#   - Define a `budget` variable with an initial value of 200.
#
#   - Create two empty lists called `item_names_list` and `item_prices_list` to store the name and price of each item separately.

# %%
# Write your code here
budget = 200
item_names_list = []
item_prices_list = []

# %% [markdown]
# 2. Functions:
#   - Write a function `add_item_to_cart(item_name, item_price)` that takes the item’s name and price as arguments, appends the name to item_names and the price to item_prices, and returns both updated lists.
#
#   - Write a function `calculate_total(item_prices)` that calculates and returns the total cost of all items in item_prices.
#
#     Conditions:
#     - If the total cost exceeds the budget after adding an item, print "Budget exceeded!" and stop adding more items.
#     - If the total cost is within budget and exceeds $100, apply a 10% discount on the total and print the discounted total.

# %%
# Write your code here
def add_item_to_cart(item_name, item_price):
    item_names_list.append(item_name)
    item_prices_list.append(item_price)
    return item_names_list, item_prices_list

def calculate_total(item_prices):
    return sum(item_prices)

# %% [markdown]
# 3.	Loop and Input:
#   - Start the input only once the user says 'start'
#   - Use a loop to allow the user to add items to the cart by entering an item name and price. The loop should stop when the user types 'done'.
#   - For each item, add it to item_names and item_prices using add_item_to_cart, then update the total cost using calculate_total.
#
# Output:
#   - After the loop ends, display the final cart with each item and its price, the initial total, any applicable discount, and the final total.

# %%
# Write your code here
def shopping_cart():
    print("Type 'start' to begin adding items.")
    user_input = input().lower()

    if user_input != 'start':
        print("You did not start the program.")
        return

    while True:
        item_name = input("Enter item name (or type 'done' to finish): ")
        if item_name.lower() == 'done':
            break

        try:
            item_price = float(input(f"Enter price for {item_name}: $"))
        except ValueError:
            print("Invalid price. Please enter a number.")
            continue

        # Add item to cart and update total
        add_item_to_cart(item_name, item_price)
        total_cost = calculate_total(item_prices_list)

        if total_cost > budget:
            print("Budget exceeded!")
            break

    # Display final cart
    print("\nFinal Cart:")
    for i in range(len(item_names_list)):
        print(f"{item_names_list[i]}: ${item_prices_list[i]:.2f}")

    # Calculate total and apply discount if necessary
    total_cost = calculate_total(item_prices_list)
    print(f"\nInitial Total: ${total_cost:.2f}")
    if total_cost > 100:
        discount = total_cost * 0.10
        total_cost -= discount
        print(f"Discount applied: 10% off\nDiscounted Total: ${total_cost:.2f}")
    else:
        print(f"Final Total: ${total_cost:.2f}")

shopping_cart()
# Out:
# Type 'start' to begin adding items.
# h
# You did not start the program.

# %%
# Write your code here

# %% [markdown]
# # Section 2 - Intermidiate (55%) - Remote Work and Mental Health Analysis
#
# Dataset source: Kaggle (https://www.kaggle.com/datasets/waqi786/remote-work-and-mental-health)

# %% [markdown]
# ## Objective:
# - In the following sections, you will explore the "Remote Work and Mental Health" dataset using Python and different data science libraries such as Pandas, NumPy and Matplotlib.
# - Follow the instructions below to complete each task. Please provide code for each question and any observations as comments when necessary.

# %%
# Import necessary modules and libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Load Dataset (2 marks)
# - Instructions: Load the dataset using Pandas and display few rows.
# - Question: Describe the overall structure (rows, columns, data types) as a comment at the end of your code.

# %%
# Write code here
# Load the dataset
url = "https://raw.githubusercontent.com/AMANBHA1/Data-Analytics-Workshop/refs/heads/main/Assessment/dataset.csv"
df = pd.read_csv(url)

# %% [markdown]
# ## 2. Display 'n' Rows (3 marks)
# - Instructions: Display the first 13 rows of the dataset.

# %%
# Write code here
# Display the first 13 rows
print("\nFirst 13 rows:")
print(df.head(13))
# Out:
# First 13 rows:
#    Employee_ID  Age             Gender           Job_Role       Industry  \
# 0      EMP0001   32         Non-binary                 HR     Healthcare
# 1      EMP0002   40             Female     Data Scientist             IT
# 2      EMP0003   59         Non-binary  Software Engineer      Education
# 3      EMP0004   27               Male  Software Engineer        Finance
# 4      EMP0005   49               Male              Sales     Consulting
# 5      EMP0006   59         Non-binary              Sales             IT
# 6      EMP0007   31  Prefer not to say              Sales             IT
# 7      EMP0008   42         Non-binary     Data Scientist  Manufacturing
# 8      EMP0009   56  Prefer not to say     Data Scientist     Healthcare
# 9      EMP0010   30             Female                 HR             IT
# 10     EMP0011   33         Non-binary  Software Engineer        Finance
# 11     EMP0012   47             Female          Marketing     Consulting
# 12     EMP0013   40             Female          Marketing     Consulting
#
#     Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                    13        Hybrid                     47
# 1                     3        Remote                     52
# 2                    22        Hybrid                     46
# 3                    20        Onsite                     32
# 4                    32        Onsite                     35
# 5                    31        Hybrid                     39
# 6                    24        Remote                     51
# 7                     6        Onsite                     54
# 8                     9        Hybrid                     24
# 9                    28        Hybrid                     57
# 10                   17        Remote                     48
# 11                   31        Hybrid                     26
# 12                    1        Remote                     21
#
#     Number_of_Virtual_Meetings  Work_Life_Balance_Rating Stress_Level  \
# 0                            7                         2       Medium
# 1                            4                         1       Medium
# 2                           11                         5       Medium
# 3                            8                         4         High
# 4                           12                         2         High
# 5                            3                         4         High
# 6                            7                         3          Low
# 7                            7                         3       Medium
# 8                            4                         2         High
# 9                            6                         1          Low
# 10                           3                         3         High
# 11                          12                         4       Medium
# 12                           7                         2         High
#
#    Mental_Health_Condition Access_to_Mental_Health_Resources  \
# 0               Depression                                No
# 1                  Anxiety                                No
# 2                  Anxiety                                No
# 3               Depression                               Yes
# 4                      NaN                               Yes
# 5                      NaN                                No
# 6                  Anxiety                               Yes
# 7               Depression                                No
# 8                      NaN                               Yes
# 9               Depression                               Yes
# 10                     NaN                               Yes
# 11                     NaN                               Yes
# 12              Depression                               Yes
#
#    Productivity_Change  Social_Isolation_Rating Satisfaction_with_Remote_Work  \
# 0             Decrease                        1                   Unsatisfied
# 1             Increase                        3                     Satisfied
# 2            No Change                        4                   Unsatisfied
# 3             Increase                        3                   Unsatisfied
# 4             Decrease                        3                   Unsatisfied
# 5             Increase                        5                   Unsatisfied
# 6             Decrease                        5                       Neutral
# 7             Decrease                        5                     Satisfied
# 8             Decrease                        2                   Unsatisfied
# 9             Decrease                        2                       Neutral
# 10            Decrease                        4                     Satisfied
# 11           No Change                        4                       Neutral
# 12            Decrease                        2                       Neutral
#
#     Company_Support_for_Remote_Work Physical_Activity Sleep_Quality  \
# 0                                 1            Weekly          Good
# 1                                 2            Weekly          Good
# 2                                 5               NaN          Poor
# 3                                 3               NaN          Poor
# 4                                 3            Weekly       Average
# 5                                 1               NaN       Average
# 6                                 3             Daily          Poor
# 7                                 4               NaN       Average
# 8                                 4             Daily          Poor
# 9                                 1            Weekly          Poor
# 10                                2            Weekly       Average
# 11                                3            Weekly          Poor
# 12                                1            Weekly          Good
#
#            Region
# 0          Europe
# 1            Asia
# 2   North America
# 3          Europe
# 4   North America
# 5   South America
# 6            Asia
# 7   North America
# 8          Europe
# 9   North America
# 10        Oceania
# 11         Africa
# 12         Europe

# %% [markdown]
# - Instructions: Display the last 7 rows of the dataset

# %%
# Write code here
# Display the last 7 rows
print("\nLast 7 rows:")
print(df.tail(7))
# Out:
# Last 7 rows:
#      Employee_ID  Age             Gender   Job_Role    Industry  \
# 4993     EMP4994   35         Non-binary  Marketing      Retail
# 4994     EMP4995   40  Prefer not to say  Marketing          IT
# 4995     EMP4996   32               Male      Sales  Consulting
# 4996     EMP4997   39             Female      Sales  Healthcare
# 4997     EMP4998   42             Female      Sales  Healthcare
# 4998     EMP4999   27             Female      Sales  Healthcare
# 4999     EMP5000   29               Male         HR          IT
#
#       Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 4993                   12        Hybrid                     32
# 4994                   17        Hybrid                     52
# 4995                    4        Onsite                     24
# 4996                   27        Onsite                     48
# 4997                   21        Hybrid                     34
# 4998                   26        Remote                     58
# 4999                   30        Onsite                     20
#
#       Number_of_Virtual_Meetings  Work_Life_Balance_Rating Stress_Level  \
# 4993                          13                         5       Medium
# 4994                           1                         2       Medium
# 4995                           2                         5         High
# 4996                          15                         1          Low
# 4997                           1                         4         High
# 4998                           0                         5          Low
# 4999                          15                         1          Low
#
#      Mental_Health_Condition Access_to_Mental_Health_Resources  \
# 4993                     NaN                               Yes
# 4994                 Burnout                               Yes
# 4995                 Burnout                               Yes
# 4996              Depression                               Yes
# 4997                 Burnout                                No
# 4998                     NaN                               Yes
# 4999              Depression                               Yes
#
#      Productivity_Change  Social_Isolation_Rating  \
# 4993            Decrease                        2
# 4994            Increase                        3
# 4995            Decrease                        4
# 4996            Decrease                        1
# 4997            Increase                        3
# 4998            Increase                        3
# 4999           No Change                        3
#
#      Satisfaction_with_Remote_Work  Company_Support_for_Remote_Work  \
# 4993                     Satisfied                                3
# 4994                       Neutral                                5
# 4995                       Neutral                                1
# 4996                     Satisfied                                1
# 4997                     Satisfied                                1
# 4998                   Unsatisfied                                4
# 4999                   Unsatisfied                                5
#
#      Physical_Activity Sleep_Quality   Region
# 4993             Daily          Good     Asia
# 4994             Daily          Good  Oceania
# 4995            Weekly       Average     Asia
# 4996               NaN       Average   Africa
# 4997             Daily          Poor  Oceania
# 4998             Daily       Average     Asia
# 4999               NaN          Poor     Asia

# %% [markdown]
# ## 3. Find the Number of Null Values in the Dataset (2 mark)

# %%
# Write code here
print("\nNull Values:")
print(df.isnull().sum())
# Out:
# Null Values:
# Employee_ID                             0
# Age                                     0
# Gender                                  0
# Job_Role                                0
# Industry                                0
# Years_of_Experience                     0
# Work_Location                           0
# Hours_Worked_Per_Week                   0
# Number_of_Virtual_Meetings              0
# Work_Life_Balance_Rating                0
# Stress_Level                            0
# Mental_Health_Condition              1196
# Access_to_Mental_Health_Resources       0
# Productivity_Change                     0
# Social_Isolation_Rating                 0
# Satisfaction_with_Remote_Work           0
# Company_Support_for_Remote_Work         0
# Physical_Activity                    1629
# Sleep_Quality                           0
# Region                                  0
# dtype: int64

# %% [markdown]
# ## 4. Statistical Summary for Numeric Columns (10 marks)
# Instructions: Use individual commands to find the statistical summary.

# %% [markdown]
# - Count

# %%
# Write code here
# Count
print("\nCount:")
print(df.count())
# Out:
# Count:
# Employee_ID                          5000
# Age                                  5000
# Gender                               5000
# Job_Role                             5000
# Industry                             5000
# Years_of_Experience                  5000
# Work_Location                        5000
# Hours_Worked_Per_Week                5000
# Number_of_Virtual_Meetings           5000
# Work_Life_Balance_Rating             5000
# Stress_Level                         5000
# Mental_Health_Condition              3804
# Access_to_Mental_Health_Resources    5000
# Productivity_Change                  5000
# Social_Isolation_Rating              5000
# Satisfaction_with_Remote_Work        5000
# Company_Support_for_Remote_Work      5000
# Physical_Activity                    3371
# Sleep_Quality                        5000
# Region                               5000
# dtype: int64

# %% [markdown]
# - Mean

# %%
# Write code here
# Mean
print("\nMean:")
print(df.mean(numeric_only=True))
# Out:
# Mean:
# Age                                40.9950
# Years_of_Experience                17.8102
# Hours_Worked_Per_Week              39.6146
# Number_of_Virtual_Meetings          7.5590
# Work_Life_Balance_Rating            2.9842
# Social_Isolation_Rating             2.9938
# Company_Support_for_Remote_Work     3.0078
# dtype: float64

# %% [markdown]
# - Standard Deviation

# %%
# Write code here
# Standard Deviation
print("\nStandard Deviation:")
print(df.std(numeric_only=True))
# Out:
# Standard Deviation:
# Age                                11.296021
# Years_of_Experience                10.020412
# Hours_Worked_Per_Week              11.860194
# Number_of_Virtual_Meetings          4.636121
# Work_Life_Balance_Rating            1.410513
# Social_Isolation_Rating             1.394615
# Company_Support_for_Remote_Work     1.399046
# dtype: float64

# %% [markdown]
# - Quartiles

# %%
# Write code here
# Filter only numeric columns
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# Calculate quartiles
print("\nQuartiles:")
print(numeric_df.quantile([0.25, 0.5, 0.75]))
# Out:
# Quartiles:
#        Age  Years_of_Experience  Hours_Worked_Per_Week  \
# 0.25  31.0                  9.0                   29.0
# 0.50  41.0                 18.0                   40.0
# 0.75  51.0                 26.0                   50.0
#
#       Number_of_Virtual_Meetings  Work_Life_Balance_Rating  \
# 0.25                         4.0                       2.0
# 0.50                         8.0                       3.0
# 0.75                        12.0                       4.0
#
#       Social_Isolation_Rating  Company_Support_for_Remote_Work
# 0.25                      2.0                              2.0
# 0.50                      3.0                              3.0
# 0.75                      4.0                              4.0

# %% [markdown]
# ## 5. Calculate Extrema (2 marks)

# %%
# Write code here
print("\nMin and Max values:")
print(df.min(numeric_only=True))
print(df.max(numeric_only=True))
# Out:
# Min and Max values:
# Age                                22
# Years_of_Experience                 1
# Hours_Worked_Per_Week              20
# Number_of_Virtual_Meetings          0
# Work_Life_Balance_Rating            1
# Social_Isolation_Rating             1
# Company_Support_for_Remote_Work     1
# dtype: int64
# Age                                60
# Years_of_Experience                35
# Hours_Worked_Per_Week              60
# Number_of_Virtual_Meetings         15
# Work_Life_Balance_Rating            5
# Social_Isolation_Rating             5
# Company_Support_for_Remote_Work     5
# dtype: int64

# %% [markdown]
# ## 6. Find Unique Values in a Categorical Column (3 marks)
#
# - Instructions: Identify the unique values in the `job_role` column (2 marks)
# - Question: How many unique roles are represented in the dataset? (1 mark)

# %%
# Step 6: Find unique job roles
unique_roles = df['Job_Role'].unique()
print("\nUnique Job Roles:", unique_roles)
print("Number of Unique Job Roles:", len(unique_roles))
# Out:
# Unique Job Roles: ['HR' 'Data Scientist' 'Software Engineer' 'Sales' 'Marketing' 'Designer'
#  'Project Manager']
# Number of Unique Job Roles: 7

# %% [markdown]
# ## 7. Group Data and Calculate Mean (4 marks)
# - Instructions: Group the dataset by `job_role` and calculate the mean of the `Work_Life_Balance_Rating` for each role.
# - Question: Which job role has the highest average Work life balance?

# %%
# Step 7: Group by Job_Role and calculate mean of Work_Life_Balance_Rating
work_life_balance_mean = df.groupby('Job_Role')['Work_Life_Balance_Rating'].mean()
print("\nAverage Work Life Balance Rating by Job Role:")
print(work_life_balance_mean)

# Find the job role with the highest average work-life balance rating
print("Highest Average Work Life Balance:", work_life_balance_mean.idxmax())
# Out:
# Average Work Life Balance Rating by Job Role:
# Job_Role
# Data Scientist       3.007184
# Designer             2.966805
# HR                   2.930168
# Marketing            2.945827
# Project Manager      2.960705
# Sales                3.043656
# Software Engineer    3.033755
# Name: Work_Life_Balance_Rating, dtype: float64
# Highest Average Work Life Balance: Sales

# %% [markdown]
# ## 8. Filter Data Based on Condition (4 marks)
# - Instructions: Filter the dataset to show only rows where `work_hours_per_week` is greater than 40.
# - Question: How many employees are working overtime?

# %%
# Write code here
# Step 8: Filter rows where Hours_Worked_Per_Week > 40
overtime_employees = df[df['Hours_Worked_Per_Week'] > 40]
print("\nNumber of employees working overtime:", len(overtime_employees))
# Out:
# Number of employees working overtime: 2384

# %% [markdown]
# ## 9 . Histogram of Work Hours per Week (5 marks)
# - Instructions: Create a histogram of `Hours_Worked_Per_Week` (4 marks).
# - Question: Describe the distribution of work hours. Are most employees working around a certain number of hours per week? (1 mark)

# %%
# Step 9: Create a histogram of 'Hours_Worked_Per_Week'
plt.hist(df['Hours_Worked_Per_Week'], bins=10, edgecolor='black')
plt.title("Distribution of Hours Worked Per Week")
plt.xlabel("Hours Worked Per Week")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# Interpretation
print("Distribution of work hours per week has been visualized.")
# Out:
# Distribution of work hours per week has been visualized.

# %% [markdown]
# ## 10. Scatter Plot of Work Hours vs. Years_of_Experience (4 marks)
# - Instructions: Create a scatter plot with `Hours_Worked_Per_Week` on the x-axis and `Years_of_Experience` on the y-axis.

# %%
# Write code here
# Step 10: Scatter plot for Hours Worked vs. Years of Experience
plt.scatter(df['Hours_Worked_Per_Week'], df['Years_of_Experience'], alpha=0.6)
plt.title("Hours Worked Per Week vs. Years of Experience")
plt.xlabel("Hours Worked Per Week")
plt.ylabel("Years of Experience")
plt.grid(True)
plt.show()

# Interpretation
print("Scatter plot created for Hours Worked vs. Years of Experience.")
# Out:
# Scatter plot created for Hours Worked vs. Years of Experience.

# %% [markdown]
# ## 11. Bar Chart of Average Work Life Balance by Job Role (5 marks)
# - Instructions: Create a bar chart showing the average `Work_Life_Balance_Rating` for each `Job_Role` (4 marks).
# - Question: Which job roles have the highest and lowest average mental Work Life Balance? (1 mark)

# %%
# Write code here
# Step 11: Bar chart of average Work Life Balance Rating by Job Role
work_life_balance_mean = df.groupby('Job_Role')['Work_Life_Balance_Rating'].mean()

# Plot the bar chart
work_life_balance_mean.plot(kind='bar', figsize=(10, 6), edgecolor='black')
plt.title("Average Work Life Balance Rating by Job Role")
plt.xlabel("Job Role")
plt.ylabel("Average Work Life Balance Rating")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# Interpretation
print("Bar chart created for Average Work Life Balance Rating by Job Role.")
# Out:
# Bar chart created for Average Work Life Balance Rating by Job Role.

# %% [markdown]
# ## 12. Pie Chart of Workload Level Distribution (5 marks)
# - Instructions: Use a pie chart to show the proportion of `Access_to_Mental_Health_Resources` (Yes and no) in the dataset (4 marks).
# - Question: What percentage of employees have access to mental health resources? (1 mark)

# %%
# Write code here
# Step 12: Pie chart for Access to Mental Health Resources
mental_health_access = df['Access_to_Mental_Health_Resources'].value_counts()

# Plot the pie chart
mental_health_access.plot(kind='pie', autopct='%1.1f%%', startangle=90, figsize=(8, 8))
plt.title("Access to Mental Health Resources")
plt.ylabel("")
plt.show()

# Interpretation
print(f"\nPercentage of employees with access to mental health resources:\n{mental_health_access}")
# Out:
# Percentage of employees with access to mental health resources:
# Access_to_Mental_Health_Resources
# No     2553
# Yes    2447
# Name: count, dtype: int64

# %% [markdown]
# ## 13. Scatter Plot of Age vs. Social Isolation Rating (6 marks)
# - Instructions: Create a scatter plot with `age` on the x-axis and `Social_Isolation_Rating` on the y-axis (4 marks).
# - Question: Do you observe any trends or relationships between age and social isolation? Is there a noticeable impact of age on isoloation? (2 marks)

# %%
# Write code here
# Step 13: Scatter plot of Age vs. Social Isolation Rating
plt.scatter(df['Age'], df['Social_Isolation_Rating'], alpha=0.6, color='purple')
plt.title("Age vs. Social Isolation Rating")
plt.xlabel("Age")
plt.ylabel("Social Isolation Rating")
plt.grid(True)
plt.show()

# Interpretation
print("Scatter plot created for Age vs. Social Isolation Rating.")
# Out:
# Scatter plot created for Age vs. Social Isolation Rating.

# %% [markdown]
# # Section 3 - Long Answer/Advanced (20%)

# %% [markdown]
# ## Job Role and Workload Level Impact on Mental Health
#
# Instructions: Investigate the influence of job roles and workload level on the mental health.
# - Create a new column `workload_level` that labels each entry as "High" if the `Hours_Worked_Per_Week` is above its mean, otherwise "Low." (5 marks)
# - Group the dataset by `Industry` and calculate the average `Hours_Worked_Per_Week` for each combination. (5 marks)
# - Use a bar chart to display the average `Stress_Level` for each job role, with separate bars for high and low stress levels. (5 marks)
# - Analyze the results: Which job roles and workload levels appear to have the greatest impact on mental health? (5 marks)

# %%
# Write code here
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/AMANBHA1/Data-Analytics-Workshop/main/Assessment/dataset.csv"
df = pd.read_csv(url)

# Step 1

df['Workload_Level'] = ['High' if x > df['Hours_Worked_Per_Week'].mean() else 'Low' for x in df['Hours_Worked_Per_Week']]


# Step 2
industry_avg_hours = df.groupby('Industry')['Hours_Worked_Per_Week'].mean()
print("\nAverage Hours Worked Per Week by Industry:")
print(industry_avg_hours)

industry_avg_hours.plot(kind='bar', figsize=(10, 5), edgecolor='black')
plt.title("Average Hours Worked Per Week by Industry")
plt.xlabel("Industry")
plt.ylabel("Average Hours Worked")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# Step 3
stress_mapping = {'Low': 1, 'Medium': 2, 'High': 3}
df['Stress_Level_Numeric'] = df['Stress_Level'].map(stress_mapping)

stress_by_job_role = df.groupby(['Job_Role', 'Workload_Level'])['Stress_Level_Numeric'].mean().unstack()

stress_by_job_role.plot(kind='bar', figsize=(12, 6), edgecolor='black')
plt.title("Average Stress Level by Job Role and Workload Level")
plt.xlabel("Job Role")
plt.ylabel("Average Stress Level")
plt.xticks(rotation=45)
plt.legend(title='Workload Level')
plt.grid(axis='y')
plt.show()

# Step 4

overall_avg_hours = df['Hours_Worked_Per_Week'].mean()
overall_avg_stress = df['Stress_Level_Numeric'].mean()

job_role_analysis = df.groupby('Job_Role').agg({
    'Hours_Worked_Per_Week': 'mean',
    'Stress_Level_Numeric': 'mean'
}).reset_index()

job_role_analysis['High_Workload'] = job_role_analysis['Hours_Worked_Per_Week'] > overall_avg_hours
job_role_analysis['High_Stress'] = job_role_analysis['Stress_Level_Numeric'] > overall_avg_stress

high_impact_roles = job_role_analysis[(job_role_analysis['High_Workload']) & (job_role_analysis['High_Stress'])]
print("\nJob Roles with High Workload and High Stress:")
print(high_impact_roles)
# Out:
# Average Hours Worked Per Week by Industry:
# Industry
# Consulting       39.205882
# Education        39.428986
# Finance          39.192771
# Healthcare       40.067308
# IT               40.017426
# Manufacturing    40.241581
# Retail           39.150138
# Name: Hours_Worked_Per_Week, dtype: float64
# Job Roles with High Workload and High Stress:
#             Job_Role  Hours_Worked_Per_Week  Stress_Level_Numeric  \
# 4    Project Manager              39.922764              2.033875
# 5              Sales              39.860846              2.016371
# 6  Software Engineer              40.271449              2.012658
#
#    High_Workload  High_Stress
# 4           True         True
# 5           True         True
# 6           True         True
